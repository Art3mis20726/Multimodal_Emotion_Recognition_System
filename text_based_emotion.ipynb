# %%
#Load the dataset

import tensorflow as tf
import numpy as np
from datasets import load_dataset

# %%
dataset = load_dataset("go_emotions")

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 43410
#     })
#     validation: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5426
#     })
#     test: Dataset({
#         features: ['text', 'labels', 'id'],
#         num_rows: 5427
#     })
# })

# %%
# Extract text and labels
train_texts = [x['text'] for x in dataset['train']]
test_texts = [x['text'] for x in dataset['test']]
emotions = dataset['train'].features['labels'].feature.names  # Emotion categories
emotions
# Out:
# ['admiration',
#  'amusement',
#  'anger',
#  'annoyance',
#  'approval',
#  'caring',
#  'confusion',
#  'curiosity',
#  'desire',
#  'disappointment',
#  'disapproval',
#  'disgust',
#  'embarrassment',
#  'excitement',
#  'fear',
#  'gratitude',
#  'grief',
#  'joy',
#  'love',
#  'nervousness',
#  'optimism',
#  'pride',
#  'realization',
#  'relief',
#  'remorse',
#  'sadness',
#  'surprise',
#  'neutral']

# %%
len(train_texts)
# Out:
# 43410

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\GITESH\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
#Encoding labels
def one_hot_encode(examples):
    labels = np.zeros(len(emotions))
    for label in examples['labels']:
        labels[label] = 1
    return labels

# %%
train_labels = np.array([one_hot_encode(x) for x in dataset['train']])
test_labels = np.array([one_hot_encode(x) for x in dataset['test']])

# %%
train_labels.shape
# Out:
# (43410, 28)

# %%
#Lemmatizer
from nltk.stem import WordNetLemmatizer
lemmatizer=WordNetLemmatizer()

# %%
#Data Preprocessing
import re
import string
def preprocess_text(text):
    text=text.lower()
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text=re.sub('[^a-z A-z 0-9]',' ',text)
    text = text.translate(str.maketrans("", "", string.punctuation))  # Remove punctuation
    text=' '.join([lemmatizer.lemmatize(word) for word in text.split() if word not in stopwords.words('english')])
    return text

# %%
# Apply preprocessing

train_texts = [preprocess_text(text) for text in train_texts]
test_texts = [preprocess_text(text) for text in test_texts]

# %%
len(train_texts)
# Out:
# 43410

# %%
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences


tokenizer = Tokenizer()
tokenizer.fit_on_texts(train_texts)
total_words=len(tokenizer.word_index)+1
total_words
# Out:
# 22621

# %%
tokenizer.word_index
# Out:
# {'name': 1,
#  'like': 2,
#  'get': 3,
#  'love': 4,
#  'one': 5,
#  'people': 6,
#  'would': 7,
#  'good': 8,
#  'know': 9,
#  'think': 10,
#  'really': 11,
#  'time': 12,
#  'make': 13,
#  'thanks': 14,
#  'lol': 15,
#  'see': 16,
#  'thing': 17,
#  'look': 18,
#  'thank': 19,
#  'go': 20,
#  'year': 21,
#  'much': 22,
#  'still': 23,
#  'even': 24,
#  'well': 25,
#  'right': 26,
#  'want': 27,
#  'got': 28,
#  'oh': 29,
#  'guy': 30,
#  'way': 31,
#  'feel': 32,
#  'yeah': 33,
#  'need': 34,
#  'never': 35,
#  'game': 36,
#  'hope': 37,
#  'say': 38,
#  'great': 39,
#  'man': 40,
#  'bad': 41,
#  'u': 42,
#  'sorry': 43,
#  'day': 44,
#  'back': 45,
#  'going': 46,
#  'better': 47,
#  'could': 48,
#  'also': 49,
#  'someone': 50,
#  'actually': 51,
#  'mean': 52,
#  'sure': 53,
#  'pretty': 54,
#  'work': 55,
#  'thought': 56,
#  'something': 57,
#  'though': 58,
#  'best': 59,
#  'take': 60,
#  'post': 61,
#  'happy': 62,
#  'first': 63,
#  'always': 64,
#  'yes': 65,
#  'life': 66,
#  'friend': 67,
#  'made': 68,
#  'kid': 69,
#  'wow': 70,
#  'said': 71,
#  'let': 72,
#  'new': 73,
#  'point': 74,
#  'maybe': 75,
#  'glad': 76,
#  'probably': 77,
#  'comment': 78,
#  'lot': 79,
#  'keep': 80,
#  'help': 81,
#  'hate': 82,
#  'old': 83,
#  'come': 84,
#  'nice': 85,
#  'find': 86,
#  'give': 87,
#  'last': 88,
#  'ever': 89,
#  'dude': 90,
#  'getting': 91,
#  'damn': 92,
#  'sound': 93,
#  'fuck': 94,
#  'everyone': 95,
#  'wish': 96,
#  'every': 97,
#  'many': 98,
#  'try': 99,
#  'play': 100,
#  'hard': 101,
#  'anything': 102,
#  'person': 103,
#  'little': 104,
#  'wrong': 105,
#  'woman': 106,
#  'stop': 107,
#  'fun': 108,
#  'long': 109,
#  'shit': 110,
#  'tell': 111,
#  'haha': 112,
#  'show': 113,
#  'real': 114,
#  'sub': 115,
#  'cool': 116,
#  'read': 117,
#  'least': 118,
#  'use': 119,
#  'fucking': 120,
#  'nothing': 121,
#  'trying': 122,
#  'team': 123,
#  'might': 124,
#  'problem': 125,
#  'amazing': 126,
#  'enough': 127,
#  'seen': 128,
#  'anyone': 129,
#  'around': 130,
#  'ok': 131,
#  'believe': 132,
#  'true': 133,
#  'awesome': 134,
#  'please': 135,
#  'girl': 136,
#  'gonna': 137,
#  'video': 138,
#  'kind': 139,
#  'wait': 140,
#  'idea': 141,
#  'put': 142,
#  'place': 143,
#  'already': 144,
#  'funny': 145,
#  'another': 146,
#  'big': 147,
#  'two': 148,
#  'guess': 149,
#  'definitely': 150,
#  'next': 151,
#  'part': 152,
#  'sad': 153,
#  'r': 154,
#  'else': 155,
#  'weird': 156,
#  'care': 157,
#  'money': 158,
#  'end': 159,
#  'since': 160,
#  'job': 161,
#  'reason': 162,
#  'seems': 163,
#  'luck': 164,
#  'word': 165,
#  'call': 166,
#  'season': 167,
#  'remember': 168,
#  'world': 169,
#  'interesting': 170,
#  'hear': 171,
#  'im': 172,
#  'watch': 173,
#  'understand': 174,
#  'looking': 175,
#  'dont': 176,
#  'fan': 177,
#  'stupid': 178,
#  'saying': 179,
#  'live': 180,
#  'joke': 181,
#  'agree': 182,
#  'everything': 183,
#  'hell': 184,
#  'used': 185,
#  'without': 186,
#  'start': 187,
#  'far': 188,
#  'done': 189,
#  'must': 190,
#  'second': 191,
#  'literally': 192,
#  'ago': 193,
#  'child': 194,
#  'lmao': 195,
#  'bit': 196,
#  'happened': 197,
#  'away': 198,
#  'yet': 199,
#  'left': 200,
#  'favorite': 201,
#  'fact': 202,
#  'story': 203,
#  'exactly': 204,
#  'making': 205,
#  'talking': 206,
#  'week': 207,
#  'heard': 208,
#  'reddit': 209,
#  'face': 210,
#  'feeling': 211,
#  'home': 212,
#  'player': 213,
#  'different': 214,
#  'went': 215,
#  'saw': 216,
#  'head': 217,
#  'suck': 218,
#  'either': 219,
#  'high': 220,
#  'talk': 221,
#  'op': 222,
#  'imagine': 223,
#  'change': 224,
#  'enjoy': 225,
#  'honestly': 226,
#  'whole': 227,
#  'mind': 228,
#  'win': 229,
#  'stuff': 230,
#  'question': 231,
#  'may': 232,
#  'today': 233,
#  'school': 234,
#  'less': 235,
#  'almost': 236,
#  'playing': 237,
#  'stay': 238,
#  'hey': 239,
#  'month': 240,
#  'surprised': 241,
#  'news': 242,
#  'dog': 243,
#  'boy': 244,
#  'family': 245,
#  'poor': 246,
#  'worse': 247,
#  'absolutely': 248,
#  'omg': 249,
#  'okay': 250,
#  'super': 251,
#  'beautiful': 252,
#  'hit': 253,
#  'worst': 254,
#  'ah': 255,
#  'free': 256,
#  'terrible': 257,
#  'ask': 258,
#  'issue': 259,
#  'came': 260,
#  'hurt': 261,
#  'mom': 262,
#  'hour': 263,
#  'baby': 264,
#  'men': 265,
#  'crazy': 266,
#  'lost': 267,
#  'thinking': 268,
#  'car': 269,
#  'sense': 270,
#  'matter': 271,
#  'wanted': 272,
#  'movie': 273,
#  'coming': 274,
#  'move': 275,
#  'taking': 276,
#  'hand': 277,
#  'god': 278,
#  'found': 279,
#  'wonder': 280,
#  'happen': 281,
#  'leave': 282,
#  'state': 283,
#  'cry': 284,
#  'sometimes': 285,
#  'miss': 286,
#  'cute': 287,
#  'kinda': 288,
#  'took': 289,
#  'top': 290,
#  'appreciate': 291,
#  'night': 292,
#  'check': 293,
#  'shot': 294,
#  'loved': 295,
#  'thats': 296,
#  'picture': 297,
#  'support': 298,
#  'parent': 299,
#  'run': 300,
#  'gotta': 301,
#  'sex': 302,
#  'opinion': 303,
#  'side': 304,
#  'kill': 305,
#  'watching': 306,
#  'cause': 307,
#  'seem': 308,
#  'religion': 309,
#  'moment': 310,
#  'minute': 311,
#  'pay': 312,
#  'worry': 313,
#  'able': 314,
#  'country': 315,
#  'deal': 316,
#  'cat': 317,
#  'laugh': 318,
#  'line': 319,
#  'close': 320,
#  'meme': 321,
#  'thread': 322,
#  'instead': 323,
#  'character': 324,
#  'welcome': 325,
#  'tho': 326,
#  'told': 327,
#  'half': 328,
#  'eye': 329,
#  'case': 330,
#  'turn': 331,
#  'edit': 332,
#  'gun': 333,
#  'called': 334,
#  'number': 335,
#  'totally': 336,
#  'together': 337,
#  'especially': 338,
#  'fine': 339,
#  'worth': 340,
#  'idiot': 341,
#  'chance': 342,
#  'completely': 343,
#  'rather': 344,
#  'full': 345,
#  'using': 346,
#  'break': 347,
#  'human': 348,
#  'seeing': 349,
#  'eat': 350,
#  'food': 351,
#  'bro': 352,
#  'hot': 353,
#  'sweet': 354,
#  'seriously': 355,
#  'curious': 356,
#  'knew': 357,
#  'buy': 358,
#  'open': 359,
#  'awful': 360,
#  'horrible': 361,
#  'phone': 362,
#  'wife': 363,
#  'rest': 364,
#  'couple': 365,
#  'level': 366,
#  'tried': 367,
#  'realize': 368,
#  'lose': 369,
#  'article': 370,
#  'dumb': 371,
#  'happens': 372,
#  'link': 373,
#  'government': 374,
#  'heart': 375,
#  'alone': 376,
#  'situation': 377,
#  'soon': 378,
#  'pick': 379,
#  'ball': 380,
#  'experience': 381,
#  'song': 382,
#  'nah': 383,
#  'forgot': 384,
#  'quite': 385,
#  'answer': 386,
#  'anymore': 387,
#  'single': 388,
#  'ya': 389,
#  'meant': 390,
#  'relationship': 391,
#  'easy': 392,
#  'hopefully': 393,
#  'th': 394,
#  'episode': 395,
#  'book': 396,
#  'fair': 397,
#  'started': 398,
#  'fight': 399,
#  'mine': 400,
#  'excited': 401,
#  'played': 402,
#  'advice': 403,
#  'self': 404,
#  'reading': 405,
#  'house': 406,
#  'age': 407,
#  'dead': 408,
#  'perfect': 409,
#  'finally': 410,
#  'course': 411,
#  'posted': 412,
#  'past': 413,
#  'internet': 414,
#  'future': 415,
#  'k': 416,
#  'hug': 417,
#  'possible': 418,
#  'vote': 419,
#  'racist': 420,
#  'usually': 421,
#  'others': 422,
#  'dad': 423,
#  'fake': 424,
#  'tbh': 425,
#  'become': 426,
#  'sharing': 427,
#  'brother': 428,
#  'die': 429,
#  'obviously': 430,
#  'except': 431,
#  'idk': 432,
#  'looked': 433,
#  'type': 434,
#  'serious': 435,
#  'missed': 436,
#  'nobody': 437,
#  'huge': 438,
#  'shame': 439,
#  'working': 440,
#  'entire': 441,
#  'death': 442,
#  'disgusting': 443,
#  'congrats': 444,
#  'body': 445,
#  'anyway': 446,
#  'sign': 447,
#  'holy': 448,
#  'strong': 449,
#  'as': 450,
#  'city': 451,
#  'account': 452,
#  'young': 453,
#  'law': 454,
#  'v': 455,
#  'beat': 456,
#  'unfortunately': 457,
#  'cake': 458,
#  'hoping': 459,
#  'clearly': 460,
#  'unless': 461,
#  'giving': 462,
#  'party': 463,
#  'pain': 464,
#  'cant': 465,
#  'term': 466,
#  'gave': 467,
#  'mother': 468,
#  'bring': 469,
#  'low': 470,
#  'actual': 471,
#  'response': 472,
#  'water': 473,
#  'group': 474,
#  'hair': 475,
#  'non': 476,
#  'basically': 477,
#  'hilarious': 478,
#  'reply': 479,
#  'stand': 480,
#  'history': 481,
#  'late': 482,
#  'date': 483,
#  'often': 484,
#  'living': 485,
#  'felt': 486,
#  'argument': 487,
#  'power': 488,
#  'cheer': 489,
#  'outside': 490,
#  'rule': 491,
#  'forget': 492,
#  'deserve': 493,
#  'area': 494,
#  'source': 495,
#  'subreddit': 496,
#  'wanna': 497,
#  'proud': 498,
#  'yep': 499,
#  'needed': 500,
#  'whatever': 501,
#  'normal': 502,
#  'control': 503,
#  'loss': 504,
#  'sort': 505,
#  'gold': 506,
#  'learn': 507,
#  'tonight': 508,
#  'liked': 509,
#  'mate': 510,
#  'gone': 511,
#  'cold': 512,
#  'room': 513,
#  'mad': 514,
#  'safe': 515,
#  'troll': 516,
#  'three': 517,
#  'bet': 518,
#  'difference': 519,
#  'system': 520,
#  'title': 521,
#  'likely': 522,
#  'goal': 523,
#  'scared': 524,
#  'similar': 525,
#  'small': 526,
#  'white': 527,
#  'drug': 528,
#  'drive': 529,
#  'afraid': 530,
#  'son': 531,
#  'b': 532,
#  'doctor': 533,
#  'red': 534,
#  'angry': 535,
#  'expect': 536,
#  'hahaha': 537,
#  'step': 538,
#  'sick': 539,
#  'confused': 540,
#  'noticed': 541,
#  'given': 542,
#  'later': 543,
#  'dream': 544,
#  'lie': 545,
#  'calling': 546,
#  'music': 547,
#  'option': 548,
#  'cut': 549,
#  'truly': 550,
#  'straight': 551,
#  'correct': 552,
#  'ha': 553,
#  'choice': 554,
#  'pas': 555,
#  'shut': 556,
#  'act': 557,
#  'photo': 558,
#  'watched': 559,
#  'posting': 560,
#  'buddy': 561,
#  'forward': 562,
#  'class': 563,
#  'asking': 564,
#  'anti': 565,
#  'youtube': 566,
#  'interested': 567,
#  'waiting': 568,
#  'claim': 569,
#  'ugh': 570,
#  'america': 571,
#  'wall': 572,
#  'view': 573,
#  'save': 574,
#  'fire': 575,
#  'ridiculous': 576,
#  'short': 577,
#  'fall': 578,
#  'tax': 579,
#  'didnt': 580,
#  'plan': 581,
#  'lady': 582,
#  'fast': 583,
#  'based': 584,
#  'important': 585,
#  'huh': 586,
#  'respect': 587,
#  'listen': 588,
#  'pic': 589,
#  'wonderful': 590,
#  'piece': 591,
#  'ready': 592,
#  'worried': 593,
#  'killed': 594,
#  'police': 595,
#  'ugly': 596,
#  'company': 597,
#  'behind': 598,
#  'p': 599,
#  'ex': 600,
#  'died': 601,
#  'animal': 602,
#  'running': 603,
#  'doubt': 604,
#  'add': 605,
#  'sadly': 606,
#  'war': 607,
#  'yea': 608,
#  'throw': 609,
#  'birthday': 610,
#  'scene': 611,
#  'service': 612,
#  'front': 613,
#  'explain': 614,
#  'nope': 615,
#  'trust': 616,
#  'brain': 617,
#  'smile': 618,
#  'creepy': 619,
#  'drop': 620,
#  'league': 621,
#  'extremely': 622,
#  'trade': 623,
#  'wondering': 624,
#  'cringe': 625,
#  'hold': 626,
#  'adult': 627,
#  'order': 628,
#  'lucky': 629,
#  'road': 630,
#  'share': 631,
#  'amount': 632,
#  'imo': 633,
#  'crap': 634,
#  'personally': 635,
#  'original': 636,
#  'apparently': 637,
#  'early': 638,
#  'upvote': 639,
#  'black': 640,
#  'clear': 641,
#  'star': 642,
#  'foot': 643,
#  'drink': 644,
#  'common': 645,
#  'telling': 646,
#  'mistake': 647,
#  'light': 648,
#  'x': 649,
#  'round': 650,
#  'twitter': 651,
#  'figure': 652,
#  'business': 653,
#  'truth': 654,
#  'longer': 655,
#  'price': 656,
#  'downvoted': 657,
#  'husband': 658,
#  'losing': 659,
#  'match': 660,
#  'message': 661,
#  'example': 662,
#  'alright': 663,
#  'community': 664,
#  'inside': 665,
#  'taken': 666,
#  'store': 667,
#  'eating': 668,
#  'exact': 669,
#  'skin': 670,
#  'mostly': 671,
#  'attention': 672,
#  'yup': 673,
#  'changed': 674,
#  'due': 675,
#  'set': 676,
#  'yesterday': 677,
#  'surprise': 678,
#  'honest': 679,
#  'cost': 680,
#  'social': 681,
#  'million': 682,
#  'tv': 683,
#  'insane': 684,
#  'college': 685,
#  'morning': 686,
#  'reminds': 687,
#  'attack': 688,
#  'asked': 689,
#  'paid': 690,
#  'reference': 691,
#  'medium': 692,
#  'canada': 693,
#  'older': 694,
#  'excuse': 695,
#  'gotten': 696,
#  'dare': 697,
#  'middle': 698,
#  'info': 699,
#  'tip': 700,
#  'walk': 701,
#  'cop': 702,
#  'society': 703,
#  'public': 704,
#  'fit': 705,
#  'catch': 706,
#  'mental': 707,
#  'blame': 708,
#  'reality': 709,
#  'sentence': 710,
#  'forever': 711,
#  'space': 712,
#  'decision': 713,
#  'pizza': 714,
#  'considering': 715,
#  'hi': 716,
#  'position': 717,
#  'bunch': 718,
#  'near': 719,
#  'killing': 720,
#  'congratulation': 721,
#  'president': 722,
#  'username': 723,
#  'scary': 724,
#  'bottom': 725,
#  'fantastic': 726,
#  'general': 727,
#  'sleep': 728,
#  'wear': 729,
#  'health': 730,
#  'list': 731,
#  'stranger': 732,
#  'somehow': 733,
#  'mr': 734,
#  'action': 735,
#  'stick': 736,
#  'speak': 737,
#  'upset': 738,
#  'ended': 739,
#  'main': 740,
#  'spend': 741,
#  'somewhere': 742,
#  'double': 743,
#  'etc': 744,
#  'assume': 745,
#  'conversation': 746,
#  'kept': 747,
#  'political': 748,
#  'fat': 749,
#  'hero': 750,
#  'alive': 751,
#  'ad': 752,
#  'turned': 753,
#  'trash': 754,
#  'laughed': 755,
#  'fear': 756,
#  'town': 757,
#  'arm': 758,
#  'agreed': 759,
#  'send': 760,
#  'awkward': 761,
#  'injury': 762,
#  'effort': 763,
#  'interest': 764,
#  'offer': 765,
#  'rich': 766,
#  'simple': 767,
#  'incredibly': 768,
#  'pissed': 769,
#  'bed': 770,
#  'annoying': 771,
#  'quick': 772,
#  'fellow': 773,
#  'toxic': 774,
#  'cannot': 775,
#  'nd': 776,
#  'otherwise': 777,
#  'regret': 778,
#  'report': 779,
#  'legal': 780,
#  'genuinely': 781,
#  'anxiety': 782,
#  'banned': 783,
#  'murder': 784,
#  'door': 785,
#  'positive': 786,
#  'leg': 787,
#  'father': 788,
#  'disappointed': 789,
#  'burn': 790,
#  'special': 791,
#  'starting': 792,
#  'garbage': 793,
#  'odd': 794,
#  'simply': 795,
#  'sister': 796,
#  'online': 797,
#  'playoff': 798,
#  'married': 799,
#  'follow': 800,
#  'paying': 801,
#  'google': 802,
#  'laughing': 803,
#  'information': 804,
#  'fault': 805,
#  'taste': 806,
#  'allowed': 807,
#  'reaction': 808,
#  'trouble': 809,
#  'zero': 810,
#  'everybody': 811,
#  'ice': 812,
#  'blood': 813,
#  'dark': 814,
#  'bud': 815,
#  'teacher': 816,
#  'removed': 817,
#  'lack': 818,
#  'biggest': 819,
#  'worked': 820,
#  'clean': 821,
#  'supposed': 822,
#  'disagree': 823,
#  'pm': 824,
#  'bot': 825,
#  'student': 826,
#  'football': 827,
#  'pull': 828,
#  'drunk': 829,
#  'office': 830,
#  'wearing': 831,
#  'effect': 832,
#  'lead': 833,
#  'bar': 834,
#  'st': 835,
#  'gross': 836,
#  'af': 837,
#  'illegal': 838,
#  'quality': 839,
#  'easily': 840,
#  'pro': 841,
#  'tomorrow': 842,
#  'missing': 843,
#  'realized': 844,
#  'beer': 845,
#  'series': 846,
#  'evidence': 847,
#  'notice': 848,
#  'smell': 849,
#  'art': 850,
#  'focus': 851,
#  'blue': 852,
#  'result': 853,
#  'mouth': 854,
#  'avoid': 855,
#  'btw': 856,
#  'enjoyed': 857,
#  'write': 858,
#  'twice': 859,
#  'hang': 860,
#  'fighting': 861,
#  'version': 862,
#  'text': 863,
#  'sport': 864,
#  'tough': 865,
#  'grow': 866,
#  'complete': 867,
#  'n': 868,
#  'jealous': 869,
#  'boring': 870,
#  'decent': 871,
#  'met': 872,
#  'standard': 873,
#  'accurate': 874,
#  'mention': 875,
#  'soul': 876,
#  'count': 877,
#  'absolute': 878,
#  'exist': 879,
#  'voice': 880,
#  'color': 881,
#  'contract': 882,
#  'doesnt': 883,
#  'random': 884,
#  'learned': 885,
#  'loving': 886,
#  'bless': 887,
#  'spot': 888,
#  'defense': 889,
#  'average': 890,
#  'broken': 891,
#  'attractive': 892,
#  'science': 893,
#  'ending': 894,
#  'crime': 895,
#  'hat': 896,
#  'memory': 897,
#  'leaving': 898,
#  'happening': 899,
#  'extra': 900,
#  'plus': 901,
#  'statement': 902,
#  'putting': 903,
#  'prefer': 904,
#  'aware': 905,
#  'tear': 906,
#  'lovely': 907,
#  'liberal': 908,
#  'bear': 909,
#  'smh': 910,
#  'none': 911,
#  'jersey': 912,
#  'politics': 913,
#  'form': 914,
#  'waste': 915,
#  'shoot': 916,
#  'sexual': 917,
#  'treat': 918,
#  'expensive': 919,
#  'abuse': 920,
#  'touch': 921,
#  'along': 922,
#  'expecting': 923,
#  'recently': 924,
#  'within': 925,
#  'tired': 926,
#  'card': 927,
#  'therapy': 928,
#  'favourite': 929,
#  'f': 930,
#  'knowing': 931,
#  'dating': 932,
#  'em': 933,
#  'final': 934,
#  'porn': 935,
#  'somebody': 936,
#  'however': 937,
#  'ignorant': 938,
#  'yo': 939,
#  'girlfriend': 940,
#  'facebook': 941,
#  'driving': 942,
#  'sell': 943,
#  'barely': 944,
#  'race': 945,
#  'language': 946,
#  'mod': 947,
#  'brought': 948,
#  'mentioned': 949,
#  'deep': 950,
#  'steal': 951,
#  'hated': 952,
#  'block': 953,
#  'context': 954,
#  'ground': 955,
#  'e': 956,
#  'draft': 957,
#  'loud': 958,
#  'difficult': 959,
#  'third': 960,
#  'strange': 961,
#  'multiple': 962,
#  'page': 963,
#  'partner': 964,
#  'daughter': 965,
#  'value': 966,
#  'coach': 967,
#  'expected': 968,
#  'note': 969,
#  'compared': 970,
#  'per': 971,
#  'easier': 972,
#  'walking': 973,
#  'spent': 974,
#  'obvious': 975,
#  'court': 976,
#  'plenty': 977,
#  'certain': 978,
#  'owner': 979,
#  'min': 980,
#  'choose': 981,
#  'known': 982,
#  'hearing': 983,
#  'fix': 984,
#  'born': 985,
#  'weekend': 986,
#  'cover': 987,
#  'eh': 988,
#  'record': 989,
#  'moron': 990,
#  'career': 991,
#  'shocked': 992,
#  'update': 993,
#  'although': 994,
#  'anyways': 995,
#  'english': 996,
#  'bought': 997,
#  'sir': 998,
#  'wtf': 999,
#  'admit': 1000,
#  ...}

# %%
input_sequences_train = []
input_sequences_test=[]

for line in train_texts:  # Iterate over list of sentences
    token_list = tokenizer.texts_to_sequences([line])[0]  # Convert sentence to token sequence
    input_sequences_train.append(token_list)
for line in test_texts:  # Iterate over list of sentences
    token_list = tokenizer.texts_to_sequences([line])[0]  # Convert sentence to token sequence
    input_sequences_test.append(token_list)

# %%
train_max_sequence_length=max([len(x) for x in input_sequences_train])
train_max_sequence_length
# Out:
# 33

# %%
test_max_sequence_length=max([len(x) for x in input_sequences_test])
test_max_sequence_length
# Out:
# 18

# %%
train_padded_sequence_text=pad_sequences(input_sequences_train,padding='pre',maxlen=train_max_sequence_length,)
test_padded_sequence_text=pad_sequences(input_sequences_test,padding='pre',maxlen=train_max_sequence_length,)

# %%
X_train=train_padded_sequence_text
X_test=test_padded_sequence_text
ytrain=train_labels
ytest=test_labels

# %%
#LSTM model
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Embedding,LSTM,Dense,Dropout,Bidirectional


lstm_model=Sequential()
lstm_model.add(Embedding(total_words,100,input_length=train_max_sequence_length))
lstm_model.add(Bidirectional(LSTM(150,return_sequences=True))),
lstm_model.add(Dropout(0.2))
lstm_model.add(Bidirectional(LSTM(100)))
lstm_model.add(Dense(28,activation='softmax'))

lstm_model.compile(loss='categorical_crossentropy',optimizer='adam',metrics=['accuracy'])
lstm_model.summary()
# Out:
# d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\keras\src\layers\core\embedding.py:90: UserWarning: Argument `input_length` is deprecated. Just remove it.
#   warnings.warn(
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ embedding (Embedding)           │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional (Bidirectional)   │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ ?                      │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ bidirectional_1 (Bidirectional) │ ?                      │   0 (unbuilt) │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ ?                      │   0 (unbuilt) │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 0 (0.00 B)
#  Trainable params: 0 (0.00 B)
#  Non-trainable params: 0 (0.00 B)

# %%
X_train.shape
# Out:
# (43410, 33)

# %%
X_test.shape
# Out:
# (5427, 33)

# %%
ytrain.shape
# Out:
# (43410, 28)

# %%
ytest.shape
# Out:
# (5427, 28)

# %%
#train the model
history=lstm_model.fit(X_train,ytrain,epochs=10,batch_size=25,validation_data=(X_test,ytest),verbose=1)
# Out:
# Epoch 1/10
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[27], line 2
#       1 #train the model
# ----> 2 history=lstm_model.fit(X_train,ytrain,epochs=10,batch_size=25,validation_data=(X_test,ytest),verbose=1)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\keras\src\utils\traceback_utils.py:117, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     115 filtered_tb = None
#     116 try:
# --> 117     return fn(*args, **kwargs)
#     118 except Exception as e:
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:371, in TensorFlowTrainer.fit(self, x, y, batch_size, epochs, verbose, callbacks, validation_split, validation_data, shuffle, class_weight, sample_weight, initial_epoch, steps_per_epoch, validation_steps, validation_batch_size, validation_freq)
#     369 for step, iterator in epoch_iterator:
#     370     callbacks.on_train_batch_begin(step)
# --> 371     logs = self.train_function(iterator)
#     372     callbacks.on_train_batch_end(step, logs)
#     373     if self.stop_training:
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\keras\src\backend\tensorflow\trainer.py:219, in TensorFlowTrainer._make_function.<locals>.function(iterator)
#     215 def function(iterator):
#     216     if isinstance(
#     217         iterator, (tf.data.Iterator, tf.distribute.DistributedIterator)
#     218     ):
# --> 219         opt_outputs = multi_step_on_iterator(iterator)
#     220         if not opt_outputs.has_value():
#     221             raise StopIteration
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\util\traceback_utils.py:150, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     148 filtered_tb = None
#     149 try:
# --> 150   return fn(*args, **kwargs)
#     151 except Exception as e:
#     152   filtered_tb = _process_traceback_frames(e.__traceback__)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:833, in Function.__call__(self, *args, **kwds)
#     830 compiler = "xla" if self._jit_compile else "nonXla"
#     832 with OptionalXlaContext(self._jit_compile):
# --> 833   result = self._call(*args, **kwds)
#     835 new_tracing_count = self.experimental_get_tracing_count()
#     836 without_tracing = (tracing_count == new_tracing_count)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\polymorphic_function.py:919, in Function._call(self, *args, **kwds)
#     913   # If we did not create any variables the trace we have is good enough.
#     914   filtered_flat_args = (
#     915       self._concrete_variable_creation_fn.function_type.unpack_inputs(
#     916           bound_args
#     917       )
#     918   )
# --> 919   return self._concrete_variable_creation_fn._call_flat(  # pylint: disable=protected-access
#     920       filtered_flat_args,
#     921       self._concrete_variable_creation_fn.captured_inputs,
#     922   )
#     924 def fn_with_cond(inner_args, inner_kwds):
#     925   """Conditionally runs initialization if it's needed."""
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\concrete_function.py:1322, in ConcreteFunction._call_flat(self, tensor_inputs, captured_inputs)
#    1318 possible_gradient_type = gradients_util.PossibleTapeGradientTypes(args)
#    1319 if (possible_gradient_type == gradients_util.POSSIBLE_GRADIENT_TYPES_NONE
#    1320     and executing_eagerly):
#    1321   # No tape is watching; skip to running the function.
# -> 1322   return self._inference_function.call_preflattened(args)
#    1323 forward_backward = self._select_forward_and_backward_functions(
#    1324     args,
#    1325     possible_gradient_type,
#    1326     executing_eagerly)
#    1327 forward_function, args_with_tangents = forward_backward.forward()
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:216, in AtomicFunction.call_preflattened(self, args)
#     214 def call_preflattened(self, args: Sequence[core.Tensor]) -> Any:
#     215   """Calls with flattened tensor inputs and returns the structured output."""
# --> 216   flat_outputs = self.call_flat(*args)
#     217   return self.function_type.pack_output(flat_outputs)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\polymorphic_function\atomic_function.py:251, in AtomicFunction.call_flat(self, *args)
#     249 with record.stop_recording():
#     250   if self._bound_context.executing_eagerly():
# --> 251     outputs = self._bound_context.call_function(
#     252         self.name,
#     253         list(args),
#     254         len(self.function_type.flat_outputs),
#     255     )
#     256   else:
#     257     outputs = make_call_op_in_graph(
#     258         self,
#     259         list(args),
#     260         self._bound_context.function_call_options.as_attrs(),
#     261     )
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\context.py:1688, in Context.call_function(self, name, tensor_inputs, num_outputs)
#    1686 cancellation_context = cancellation.context()
#    1687 if cancellation_context is None:
# -> 1688   outputs = execute.execute(
#    1689       name.decode("utf-8"),
#    1690       num_outputs=num_outputs,
#    1691       inputs=tensor_inputs,
#    1692       attrs=attrs,
#    1693       ctx=self,
#    1694   )
#    1695 else:
#    1696   outputs = execute.execute_with_cancellation(
#    1697       name.decode("utf-8"),
#    1698       num_outputs=num_outputs,
#    (...)
#    1702       cancellation_manager=cancellation_context,
#    1703   )
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tensorflow\python\eager\execute.py:53, in quick_execute(op_name, num_outputs, inputs, attrs, ctx, name)
#      51 try:
#      52   ctx.ensure_initialized()
# ---> 53   tensors = pywrap_tfe.TFE_Py_Execute(ctx._handle, device_name, op_name,
#      54                                       inputs, attrs, num_outputs)
#      55 except core._NotOkStatusException as e:
#      56   if name is not None:
#
# KeyboardInterrupt:

# %%
import tensorflow as tf
import numpy as np
from datasets import load_dataset
from transformers import AutoTokenizer, TFBertModel
from tensorflow.keras.utils import to_categorical

# Load dataset
dataset = load_dataset("go_emotions")

# Extract text and labels
train_texts = [x['text'] for x in dataset['train']]
test_texts = [x['text'] for x in dataset['test']]
emotions = dataset['train'].features['labels'].feature.names  # Emotion categories

# One-hot encode labels
def one_hot_encode(examples):
    labels = np.zeros(len(emotions))
    for label in examples['labels']:
        labels[label] = 1
    return labels

train_labels = np.array([one_hot_encode(x) for x in dataset['train']])
test_labels = np.array([one_hot_encode(x) for x in dataset['test']])

# Load BERT Tokenizer
tokenizer = AutoTokenizer.from_pretrained("bert-base-uncased")

# Tokenize text data
MAX_LENGTH = 50  # Adjust based on dataset
train_encodings = tokenizer(train_texts, truncation=True, padding=True, max_length=MAX_LENGTH, return_tensors="np")
test_encodings = tokenizer(test_texts, truncation=True, padding=True, max_length=MAX_LENGTH, return_tensors="np")

# %%
from tensorflow.keras import layers, models

# Load BERT Model
bert_model = TFBertModel.from_pretrained("bert-base-uncased")

# Define model architecture
input_ids = layers.Input(shape=(MAX_LENGTH,), dtype=tf.int32, name="input_ids")
attention_mask = layers.Input(shape=(MAX_LENGTH,), dtype=tf.int32, name="attention_mask")

# Get BERT embeddings
bert_output = bert_model(input_ids, attention_mask=attention_mask)[0][:, 0, :]  # CLS token output

# Classification head
x = layers.Dense(128, activation="relu")(bert_output)
x = layers.Dropout(0.3)(x)
output = layers.Dense(len(emotions), activation="sigmoid")(x)  # Multi-label classification

# Create model
bert_classifier = models.Model(inputs=[input_ids, attention_mask], outputs=output)

# Compile model
bert_classifier.compile(optimizer=tf.keras.optimizers.Adam(learning_rate=2e-5),
                        loss="binary_crossentropy",  # Multi-label classification loss
                        metrics=["accuracy"])
# Out:
# Some weights of the PyTorch model were not used when initializing the TF 2.0 model TFBertModel: ['cls.predictions.transform.LayerNorm.bias', 'cls.predictions.transform.dense.bias', 'cls.seq_relationship.bias', 'cls.predictions.bias', 'cls.predictions.transform.dense.weight', 'cls.predictions.transform.LayerNorm.weight', 'cls.seq_relationship.weight']
# - This IS expected if you are initializing TFBertModel from a PyTorch model trained on another task or with another architecture (e.g. initializing a TFBertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing TFBertModel from a PyTorch model that you expect to be exactly identical (e.g. initializing a TFBertForSequenceClassification model from a BertForSequenceClassification model).
# All the weights of TFBertModel were initialized from the PyTorch model.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use TFBertModel for predictions without further training.
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[33], line 11
#       8 attention_mask = layers.Input(shape=(MAX_LENGTH,), dtype=tf.int32, name="attention_mask")
#      10 # Get BERT embeddings
# ---> 11 bert_output = bert_model(input_ids, attention_mask=attention_mask)[0][:, 0, :]  # CLS token output
#      13 # Classification head
#      14 x = layers.Dense(128, activation="relu")(bert_output)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\tf_keras\src\utils\traceback_utils.py:70, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#      67     filtered_tb = _process_traceback_frames(e.__traceback__)
#      68     # To get the full stack trace, call:
#      69     # `tf.debugging.disable_traceback_filtering()`
# ---> 70     raise e.with_traceback(filtered_tb) from None
#      71 finally:
#      72     del filtered_tb
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\transformers\modeling_tf_utils.py:436, in unpack_inputs.<locals>.run_call_with_unpacked_inputs(self, *args, **kwargs)
#     433 else:
#     434     config = self.config
# --> 436 unpacked_inputs = input_processing(func, config, **fn_args_and_kwargs)
#     437 return func(self, **unpacked_inputs)
#
# File d:\Machine_Learning\NLP\Multimodal_Emotion_Recognition_System\venv\Lib\site-packages\transformers\modeling_tf_utils.py:513, in input_processing(func, config, **kwargs)
#     511         output[k] = v
#     512     else:
# --> 513         raise ValueError(f"Data of type {type(v)} is not allowed only {allowed_types} is accepted for {k}.")
#     515 if isinstance(main_input, (tuple, list)):
#     516     for i, input in enumerate(main_input):
#     517         # EagerTensors don't allow to use the .name property so we check for a real Tensor
#
# ValueError: Exception encountered when calling layer 'tf_bert_model' (type TFBertModel).
#
# Data of type <class 'keras.src.backend.common.keras_tensor.KerasTensor'> is not allowed only (<class 'tensorflow.python.framework.tensor.Tensor'>, <class 'bool'>, <class 'int'>, <class 'transformers.utils.generic.ModelOutput'>, <class 'tuple'>, <class 'list'>, <class 'dict'>, <class 'numpy.ndarray'>) is accepted for attention_mask.
#
# Call arguments received by layer 'tf_bert_model' (type TFBertModel):
#   • input_ids=<KerasTensor shape=(None, 50), dtype=int32, sparse=False, ragged=False, name=input_ids>
#   • attention_mask=<KerasTensor shape=(None, 50), dtype=int32, sparse=False, ragged=False, name=attention_mask>
#   • token_type_ids=None
#   • position_ids=None
#   • head_mask=None
#   • inputs_embeds=None
#   • encoder_hidden_states=None
#   • encoder_attention_mask=None
#   • past_key_values=None
#   • use_cache=None
#   • output_attentions=None
#   • output_hidden_states=None
#   • return_dict=None
#   • training=False
